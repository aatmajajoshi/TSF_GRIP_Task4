# %% [markdown]
# # Task 4 : Exploratory Data Analysis - Terrorism
#
# # Author - Aatmaja Joshi
#
# ## TSF GRIP TASKS
# ## Dataset link : https://drive.google.com/file/d/1luTU7xBvI7QAGPbQMxEHcgKUi9d6UeP_/view

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcdefaults()
plt.rcParams.update({'axes.facecolor':'white'})

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='latin1', engine='python')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# ## Data Preprocessing

# %%
## Columns having null values
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
## Renaming the columns
df.rename(columns = {'iyear':'Year', 'imonth':'Month', 'country_txt':'Country', 'region_txt':'Region', 'provstate':'State', 'attacktype1_txt':'Attack Type', 'targtype1_txt':'Target Type', 'targsubtype1_txt':'Target Subtype','target1':'Target', 'gname':'Group Name', 'weaptype1_txt':'Weapon Type', 'weapsubtype1_txt':'Weapon Subtype','nkill':'Killed', 'nwound':'Wounded', 'propcomment':'Property Damage'}, inplace = True)

# %%
df= df[['Year','Month','Country','Region','State','city','location','success','Attack Type','Target Type','Target Subtype','Target','Group Name','motive','Weapon Type','Weapon Subtype','Killed','Wounded','Property Damage']]
df.head()
# Out:
#    Year  Month             Country                       Region    State  \
# 0  1970      7  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0              Mexico                North America  Federal
# 2  1970      1         Philippines               Southeast Asia   Tarlac
# 3  1970      1              Greece               Western Europe   Attica
# 4  1970      1               Japan                    East Asia  Fukouka
#
#             city location  success                     Attack Type  \
# 0  Santo Domingo      NaN        1                   Assassination
# 1    Mexico city      NaN        1     Hostage Taking (Kidnapping)
# 2        Unknown      NaN        1                   Assassination
# 3         Athens      NaN        1               Bombing/Explosion
# 4        Fukouka      NaN        1  Facility/Infrastructure Attack
#
#                    Target Type  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# ...

# %%
# Now we can change the shape
df.shape
# Out:
# (181691, 19)

# %%
ctry = df['Country'].value_counts()[:50].plot.bar(figsize = (22, 10), color = 'Darkcyan')
plt.xlabel('Country', fontsize = 16)
plt.xticks(fontsize=16)
plt.title('Top 50 terrorism-prone countries', fontsize = 25)
plt.show()

# %% [markdown]
# - ### Iraq is the most terrorist prone country

# %%
region = df['Region'].value_counts()
region.plot.bar(figsize = (22,8), color = 'Maroon')
plt.xlabel('Region', fontsize = 16)
plt.xticks(fontsize = 16)
plt.title('Terrorism Prone Regions', fontsize = 25)
plt.show()

# %% [markdown]
# - ### Middle East & North Africa & South Asia are the most terrorism prone regions

# %%
target_type = df['Target Type'].value_counts()
target_type.plot.bar(figsize = (22,8), color = 'Orange')
plt.xlabel('Target Type',fontsize = 16)
plt.xticks(fontsize = 16)
plt.title('Targetted Entities', fontsize = 25)
plt.show()

# %% [markdown]
# - ### Private Citizens & Property are the most targetted entities

# %%
# Filter out 'Unknown' city beforehand if possible
filtered_df = df[df['city'] != 'Unknown']

# Count the occurrences of each city and select the top 20
top_cities = filtered_df['city'].value_counts().head(20)

# Plot the top cities
top_cities.plot.barh(figsize=(22, 8), color='blue')
plt.ylabel('City', fontsize=16)
plt.yticks(fontsize=16)
plt.title('Top 20 Cities Affected by Attacks', fontsize=25)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# - ### Baghdad is the most targetted city affected by attacks

# %%
# Replace empty values with 'Unknown' if needed
df['location'].fillna('Unknown', inplace=True)

# Filter out 'Unknown' locations beforehand if possible
filtered_df = df[df['location'] != 'Unknown']

# Count the occurrences of each location and select the top 50
top_locations = filtered_df['location'].value_counts().head(50)

# Plot the top locations
top_locations.plot.barh(figsize=(15, 20), color="#b04238")
plt.ylabel('Location', fontsize=16)
plt.yticks(fontsize=16)
plt.title('Top 20 Locations Affected by Attacks', fontsize=25)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# - ### Baghdad, Iraq is the most prominent location affected by attacks

# %%
# Replace NaN and 'Unknown' values with a consistent label, such as 'Not Specified'
df['State'].fillna('Not Specified', inplace=True)
df['State'].replace('Unknown', 'Not Specified', inplace=True)

# Filter out 'Not Specified' states beforehand if possible
filtered_df = df[df['State'] != 'Not Specified']

# Count the occurrences of each state and select the top 50
top_states = filtered_df['State'].value_counts().head(50)

# Plot the top states
top_states.plot.barh(figsize=(15, 20), color="#115f9a")  
plt.ylabel('State', fontsize=16)  
plt.yticks(fontsize=12)  
plt.title('Top 50 States Affected by Attacks', fontsize=20)  
plt.gca().invert_yaxis() 
plt.show()

# %% [markdown]
# - ### Baghdad is the most targetted state affected by attacks

# %%
plt.figure(figsize = (20,8))
sns.set_theme(style = "ticks")
sns.histplot(df, x = "Year", hue = "Region", multiple = "stack", palette = "light:m_r", edgecolor = ".3", linewidth = .5, log_scale = False)
plt.xlabel('Year', fontsize = 16)
plt.xticks(fontsize = 16)
plt.title('Region-Wise Terrorism over the years', fontsize = 25)
plt.show()

# %% [markdown]
# - ### There has been a continuous increase in terrorism since 1970, with the peak occurring in 2014

# %%
df.groupby('Attack Type')[['Killed', 'Wounded']].count()
# Out:
#                                      Killed  Wounded
# Attack Type
# Armed Assault                         40353    38392
# Assassination                         19233    17986
# Bombing/Explosion                     84322    82678
# Facility/Infrastructure Attack         9788     9656
# Hijacking                               606      592
# Hostage Taking (Barricade Incident)     898      844
# Hostage Taking (Kidnapping)            8610     8138
# Unarmed Assault                        1001      922
# Unknown                                6567     6172

# %%
attack = df.groupby('Attack Type')[['Killed', 'Wounded']].count()
attack.plot.bar(color = ['red', 'yellow'])
plt.show()

# %% [markdown]
# - ### Bombing and Explosion caused the most number of wounded people and killings

# %%
GName = df['Group Name'].value_counts().drop('Unknown')[:20]
GName.plot.barh(figsize = (22, 15))
plt.ylabel('Group Name', fontsize = 16)
plt.yticks(fontsize = 16)
plt.title('Top 20 Terrorist Groups', fontsize = 25)
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# - ### Taliban, ISIL, and SL caused the most active terrorist groups

# %%
print('Number of Successful attacks : ', df['success'].sum())
# Out:
# Number of Successful attacks :  161632

# %% [markdown]
# ## Conclusion

# %% [markdown]
#  - **Country such as Iraq are among the highest terrorist prone country**
#  - **Middle East & North Africa & South Asia are the regions most prone to terrorism**
#  - **Most of the targetted entities were private citizens and property**
#  - **Baghdad is the most prone city affected by attacks and also is the most affected state**
#  - **The location most prone to attacks was Baghdad, Iraq**
#  - **There has been a continuous increase in terrorism since 1970, with the peak occurring in 2014**
#  - **Bombing and Explosion caused the most number of wounded people and killings**
#  - **Taliban, ISIL,SL are the most active terrorist groups**

# %% [markdown]
# # ThankYou
